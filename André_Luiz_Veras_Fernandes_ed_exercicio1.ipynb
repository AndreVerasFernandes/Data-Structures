# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreVerasFernandes/Data-Structures/blob/main/Andr%C3%A9_Luiz_Veras_Fernandes_ed_exercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Este exercício envolve a implementação dos métodos **insert_element**, **remove_element**, **search_element** e **reverse_array** na classe **ArrayManipulator**. Encorajo você a preencher o código desses métodos para realizar as operações correspondentes nos arrays.

# %%
class ArrayManipulator:
    def __init__(self, array):
        self.array = array

    def get_array(self):
        return self.array

    def insert_element(self, index, element):
        """
        Insere um elemento na posição especificada do array.

        Parameters:
        - index (int): Índice onde o elemento será inserido.
        - element: Elemento a ser inserido.

        Retorna:
        - True se a inserção for bem-sucedida, False caso contrário.
        """
        self.array.insert(element, index)

        if element in self.array:
           return True
        else:
            return False

        # Implemente o código aqui
        pass

    def remove_element(self, element):
        """
        Remove a primeira ocorrência do elemento no array.

        Parameters:
        - element: Elemento a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """

        self.array.remove(element)

        if element in self.array:
           return False
        else:
            return True

        # Implemente o código aqui
        pass

    def search_element(self, element):
        """
        Procura a primeira ocorrência do elemento no array.

        Parameters:
        - element: Elemento a ser procurado.

        Retorna:
        - O índice do elemento se encontrado, ou -1 caso contrário.
        """
        return self.array.index(element)

        # Implemente o código aqui
        pass

    def reverse_array(self):
        """
        Inverte a ordem dos elementos no array.

        Retorna:
        - O array invertido.
        """
        # Implemente o código aqui
        self.array.reverse()
        return self.array
        pass

# Exemplo de uso:
array_exemplo = [1, 2, 3, 4, 5]
manipulador = ArrayManipulator(array_exemplo)

# Teste dos métodos
print("Array original:", manipulador.get_array())

# Insira um elemento na posição 2
manipulador.insert_element(2, 10)
print("Array após inserção:", manipulador.get_array())

# Remova o elemento 4
manipulador.remove_element(4)
print("Array após remoção:", manipulador.get_array())

# Procure o elemento 3
indice = manipulador.search_element(3)
print("Índice do elemento 3:", indice)

# Inverta o array
array_invertido = manipulador.reverse_array()
print("Array invertido:", array_invertido)
# Out:
# Array original: [1, 2, 3, 4, 5]
# Array após inserção: [1, 2, 3, 4, 5, 2]
# Array após remoção: [1, 2, 3, 5, 2]
# Índice do elemento 3: 2
# Array invertido: [2, 5, 3, 2, 1]

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
#
# Resposta: get_array(self): Este método retorna o array atual.
#
# insert_element(self, index, element): Este método insere um elemento na posição especificada do array. Usa-se o método insert() da classe list do Python para inserir o elemento na posição especificada. Retorna True se a inserção for bem-sucedida e False caso contrário.
#
# remove_element(self, element): Este método remove a primeira ocorrência do elemento no array. Usa-se o método remove() da classe list do Python para remover o elemento. Retorna True se a remoção for bem-sucedida e False caso contrário.
#
# search_element(self, element): Este método procura a primeira ocorrência do elemento no array. Usa-se o método index() da classe list do Python para procurar o elemento e retornar o índice. Retorna o índice do elemento se encontrado, ou -1 caso contrário.
#
# reverse_array(self): Este método inverte a ordem dos elementos no array. Usa-se o método reverse() da classe list do Python para inverter o array. Retorna o array invertido.

# %% [markdown]
# 2) Neste exercício, você deve implementar os métodos is_empty, append, prepend, delete e display na classe LinkedList. Esses métodos devem realizar operações típicas em listas ligadas, como verificar se está vazia, adicionar elementos no final ou no início, remover um elemento específico e exibir os elementos da lista. Encorajo você a preencher o código desses métodos para completar as operações na lista ligada.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None

class LinkedList:
    def __init__(self):
        self.head = None

    def is_empty(self):
        """
        Verifica se a lista está vazia.

        Retorna:
        - True se a lista estiver vazia, False caso contrário.
        """
        if self.head == None:
          return True
        else:
          return False
        # Implemente o código aqui
        pass

    def append(self, data):
        """
        Adiciona um novo nó ao final da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        new_node = Node(data)
        if self.head is None:
         self.head = new_node
         return

        current_node = self.head
        while(current_node.next_node):
         current_node = current_node.next_node

        current_node.next_node = new_node



        # Implemente o código aqui
        pass

    def prepend(self, data):
        """
        Adiciona um novo nó no início da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        new_node = Node(data)
        if self.head is None:
          self.head = new_node
        else:
          new_node.next_node = self.head
          self.head = new_node

        # Implemente o código aqui
        pass

    def delete(self, data):
        """
        Remove o primeiro nó que contém o dado especificado.

        Parameters:
        - data: Dado a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui
        current = self.head
        if current is None or current.data == data:
            self.head = current.next_node if current else None
            return

        while current.next_node:
            if current.next_node.data == data:
                current.next_node = current.next_node.next_node
                return
            current = current.next_node



        pass

    def display(self):
        """
        Exibe os elementos da lista.

        Retorna:
        - Uma representação da lista.
        """
        current_node = self.head
        output = ""
        while current_node:
          output += str(current_node.data) + " "
          current_node = current_node.next_node
          if current_node == self.head:
            break

        return output
        # Implemente o código aqui
        pass

# Exemplo de uso:
linked_list = LinkedList()

# Teste dos métodos
print("Lista vazia:", linked_list.is_empty())

# Adicione elementos ao final da lista
linked_list.append(1)
linked_list.append(2)
linked_list.append(3)

# Adicione elementos no início da lista
linked_list.prepend(0)
linked_list.prepend(-1)

print("Lista após adição:", linked_list.display())

# Remova um elemento
linked_list.delete(2)
print("Lista após remoção:", linked_list.display())
# Out:
# Lista vazia: True
# Lista após adição: -1 0 1 2 3
# Lista após remoção: -1 0 1 3

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
#
# Resposta: is_empty(self): Este método verifica se a lista está vazia. Ele retorna True se head for None (ou seja, a lista está vazia) e False caso contrário.
#
# append(self, data): Este método adiciona um novo nó ao final da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça da lista. Caso contrário, percorre-se a lista até encontrar o último nó e o adiciona ao final.
#
# prepend(self, data): Este método adiciona um novo nó no início da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça da lista. Caso contrário, o novo nó aponta para o nó atual (head) e se torna a nova cabeça da lista.
#
# delete(self, data): Este método remove o primeiro nó que contém o valor data. Se a lista estiver vazia, retorna False. Se o nó a ser removido for o primeiro nó, ajusta-se head para o próximo nó. Se o nó a ser removido estiver no meio da lista, ajusta-se os ponteiros para que o nó anterior aponte para o nó seguinte. Retorna True se o nó foi removido com sucesso e False caso contrário.
#
# display(self): Este método exibe os elementos da lista. Percorre-se a lista a partir da cabeça e imprime o valor de cada nó utilizando uma variavel output que armazena em formato de string para a faciltação de leitura.

# %% [markdown]
# 3) Neste exercício, assim como nos exemplos anteriores, você deve implementar os métodos **is_empty**, **append**, **prepend**, **delete** e **display** na classe **CircularLinkedList**. Estes métodos devem realizar operações típicas em listas ligadas circulares, como verificar se está vazia, adicionar elementos no final ou no início, remover um elemento específico e exibir os elementos da lista. Encorajo você a preencher o código desses métodos para completar as operações na lista ligada circular.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def is_empty(self):
        """
        Verifica se a lista está vazia.

        Retorna:
        - True se a lista estiver vazia, False caso contrário.
        """

        if self.head == None:
          return True
        else:
          return False
        # Implemente o código aqui
        pass

    def append(self, data):
        """
        Adiciona um novo nó ao final da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            new_node.next_node = self.head
            return

        current_node = self.head
        while current_node.next_node != self.head:
            current_node = current_node.next_node

        current_node.next_node = new_node
        new_node.next_node = self.head


        # Implemente o código aqui
        pass

    def prepend(self, data):
        """
        Adiciona um novo nó no início da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """

        new_node = Node(data)
        current_node = self.head
        new_node.next_node = self.head
        if not self.head:
          new_node.next_node = new_node
        else:
          while current_node.next_node != self.head:
            current_node = current_node.next_node
          current_node.next_node = new_node
        self.head = new_node

        # Implemente o código aqui
        pass

    def delete(self, data):
        """
        Remove o primeiro nó que contém o dado especificado.

        Parameters:
        - data: Dado a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui
        if not self.head:
            return False

        current_node = self.head
        previous_node = None
        while True:
            if current_node.data == data:
                if previous_node:
                    previous_node.next_node = current_node.next_node
                else:
                    self.head = current_node.next_node
                return True
            if current_node.next_node == self.head:
                break
            previous_node = current_node
            current_node = current_node.next_node
        return False
        pass

    def display(self):
        """
        Exibe os elementos da lista.

        Retorna:
        - Uma representação da lista.
        """
        current_node = self.head
        output = ""
        while current_node:
          output += str(current_node.data) + " "
          current_node = current_node.next_node
          if current_node == self.head:
            break

        return output

        # Implemente o código aqui
        pass

# Exemplo de uso:
circular_linked_list = CircularLinkedList()

# Teste dos métodos
print("Lista vazia:", circular_linked_list.is_empty())

# Adicione elementos ao final da lista
circular_linked_list.append(1)
circular_linked_list.append(2)
circular_linked_list.append(3)

# Adicione elementos no início da lista
circular_linked_list.prepend(0)
circular_linked_list.prepend(-1)

print("Lista após adição:", circular_linked_list.display())

# Remova um elemento
circular_linked_list.delete(2)
print("Lista após remoção:", circular_linked_list.display())
# Out:
# Lista vazia: True
# Lista após adição: -1 0 1 2 3
# Lista após remoção: -1 0 1 3

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
#
# Resposta: is_empty(self): Este método verifica se a lista está vazia. Ele retorna True se head for None (ou seja, a lista está vazia) e False caso contrário.
#
# append(self, data): Este método adiciona um novo nó ao final da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça da lista e aponta para si mesmo. Caso contrário, percorre-se a lista até encontrar o último nó (aquele cujo next_node é head) e ajusta-se os ponteiros para que o último nó aponte para o novo nó e o novo nó aponte para head.
#
# prepend(self, data): Este método adiciona um novo nó no início da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça da lista e aponta para si mesmo. Caso contrário, percorre-se a lista até encontrar o último nó (aquele cujo next_node é head) e ajusta-se os ponteiros para que o último nó aponte para o novo nó e o novo nó se torna a nova cabeça da lista.
#
# delete(self, data): Este método remove o primeiro nó que contém o valor data. Se a lista estiver vazia, retorna False. Caso contrário, percorre-se a lista até encontrar o nó com o valor data. Se o nó for encontrado, ajusta-se os ponteiros para remover o nó. Se o nó não for encontrado, retorna False..
#
# display(self): Este método exibe os elementos da lista. Percorre-se a lista a partir da cabeça e imprime o valor de cada nó utilizando uma variavel output que armazena em formato de string para a faciltação de leitura. A impressão é interrompida quando o próximo nó a ser exibido é head novamente.

# %% [markdown]
# 4) Neste exercício, como nos exemplos anteriores, você deve implementar os métodos **is_empty**, **append**, **prepend**, **delete** e **display** na classe **DoublyLinkedList**. Esses métodos devem realizar operações típicas em listas duplamente ligadas, como verificar se está vazia, adicionar elementos no final ou no início, remover um elemento específico e exibir os elementos da lista. Encorajo você a preencher o código desses métodos para completar as operações na lista duplamente ligada.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None
        self.prev_node = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def is_empty(self):
        """
        Verifica se a lista está vazia.

        Retorna:
        - True se a lista estiver vazia, False caso contrário.
        """

        if self.head == None:
          return True
        else:
          return False
        # Implemente o código aqui
        pass

    def append(self, data):
        """
        Adiciona um novo nó ao final da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """

        new_node = Node(data)
        if self.is_empty():
            self.head = self.tail = new_node
        else:
            new_node.prev_node = self.tail
            self.tail.next_node = new_node
            self.tail = new_node
        # Implemente o código aqui
        pass

    def prepend(self, data):
        """
        Adiciona um novo nó no início da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """

        new_node = Node(data)
        if self.is_empty():
            self.head = self.tail = new_node
        else:
            new_node.next_node = self.head
            self.head.prev_node = new_node
            self.head = new_node

        # Implemente o código aqui
        pass

    def delete(self, data):
        """
        Remove o primeiro nó que contém o dado especificado.

        Parameters:
        - data: Dado a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui

        current = self.head
        node_deleted = False
        if current is None:
            node_deleted = False

        elif current.data == data:
            self.head = current.next_node
            self.head.prev_node = None
            node_deleted = True

        elif self.tail.data == data:
            self.tail = self.tail.prev_node
            self.tail.next_node = None
            node_deleted = True

        else:
            while current:
                if current.data == data:
                    current.prev_node.next_node = current.next_node
                    current.next_node.prev_node = current.prev_node
                    node_deleted = True
                current = current.next_node

        if node_deleted == True:
          return True
        else:
          return False

        pass
    def display(self):
        """
        Exibe os elementos da lista.

        Retorna:
        - Uma representação da lista.
        """
        current_node = self.head
        output = ""
        while current_node:
          output += str(current_node.data) + " "
          current_node = current_node.next_node
          if current_node == self.head:
            break

        return output


        # Implemente o código aqui
        pass

# Exemplo de uso:
doubly_linked_list = DoublyLinkedList()

# Teste dos métodos
print("Lista vazia:", doubly_linked_list.is_empty())

# Adicione elementos ao final da lista
doubly_linked_list.append(1)
doubly_linked_list.append(2)
doubly_linked_list.append(3)

# Adicione elementos no início da lista
doubly_linked_list.prepend(0)
doubly_linked_list.prepend(-1)

print("Lista após adição:", doubly_linked_list.display())

# Remova um elemento
doubly_linked_list.delete(2)
print("Lista após remoção:", doubly_linked_list.display())
# Out:
# Lista vazia: True
# Lista após adição: -1 0 1 2 3
# Lista após remoção: -1 0 1 3

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
#
# Resposta: is_empty(self): Este método verifica se a lista está vazia. Ele retorna True se head for None (ou seja, a lista está vazia) e False caso contrário.
#
# append(self, data): Este método adiciona um novo nó ao final da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça e a cauda da lista. Caso contrário, ajusta-se os ponteiros para que o último nó (tail) aponte para o novo nó, o novo nó aponte para o nó anterior (prev_node), e o novo nó se torne a nova cauda da lista.
#
# prepend(self, data): Este método adiciona um novo nó no início da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça e a cauda da lista. Caso contrário, ajusta-se os ponteiros para que o primeiro nó (head) aponte para o novo nó, o novo nó aponte para o nó seguinte (next_node), e o novo nó se torne a nova cabeça da lista.
#
# delete(self, data): Este método remove o primeiro nó que contém o valor data. Se a lista estiver vazia, retorna False. Se o nó a ser removido for o primeiro nó, ajusta-se os ponteiros para que o segundo nó (next_node) se torne a nova cabeça da lista. Se o nó a ser removido for o último nó, ajusta-se os ponteiros para que o penúltimo nó (prev_node) se torne a nova cauda da lista. Se o nó a ser removido estiver no meio da lista, ajusta-se os ponteiros para que o nó anterior (prev_node) aponte para o nó seguinte (next_node) e o nó seguinte aponte para o nó anterior. Retorna True se o nó foi removido com sucesso e False caso contrário.
#
# display(self): Este método exibe os elementos da lista. Percorre-se a lista a partir da cabeça e imprime o valor de cada nó utilizando uma variavel output que armazena em formato de string para a faciltação de leitura. A impressão é interrompida quando o próximo nó a ser exibido é head novamente.

# %% [markdown]
# 5) Um exemplo do mundo real que pode ser representado eficientemente por uma estrutura de dados ligada é uma lista de reprodução de músicas em um aplicativo de música. Crie as classes Musica e PlayList de forma que o código seja capaz de:
#
#
#
# 1.   Adicionar artista e músicas à lista de reprodução;
# 2.   reproduzir a play list.

# %%
#Escreva seu código aqui!
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None
        self.prev_node = None

class Musica:
    def __init__(self, titulo, artista):
        self.titulo = titulo
        self.artista = artista

    def __str__(self):
        return f"{self.titulo} - {self.artista}"

class PlayList:
    def __init__(self):
        self.head = None
        self.tail = None

    def is_empty(self):

      if self.head == None:
          return True
      else:
          return False
      pass
    def append(self, data):

        new_node = Node(data)
        if self.is_empty():
            self.head = self.tail = new_node
        else:
            new_node.prev_node = self.tail
            self.tail.next_node = new_node
            self.tail = new_node
        pass
    def prepend(self, data):

        new_node = Node(data)
        if self.is_empty():
            self.head = self.tail = new_node
        else:
            new_node.next_node = self.head
            self.head.prev_node = new_node
            self.head = new_node
        pass
    def display(self):

        current_node = self.head
        while current_node:
            print(f"Reproduzindo: {current_node.data}")
            current_node = current_node.next_node
            if current_node == self.head:
                break
        pass


# Testando o código
playlist = PlayList()

playlist.append(Musica("Bohemian Rhapsody", "Queen"))
playlist.append(Musica("Stairway to Heaven", "Led Zeppelin"))
playlist.append(Musica("Hotel California", "Eagles"))

playlist.display()
# Out:
# Reproduzindo: Bohemian Rhapsody - Queen
# Reproduzindo: Stairway to Heaven - Led Zeppelin
# Reproduzindo: Hotel California - Eagles

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
#
# Respsota:
# class Node: Esta é uma classe que representa um nó na lista duplamente encadeada. Cada nó tem três atributos: data para armazenar o valor do nó, next_node para armazenar a referência ao próximo nó na lista e prev_node para armazenar a referência ao nó anterior na lista.
#
# class Musica: Esta é uma classe que representa uma música. Cada música tem dois atributos: titulo para armazenar o título da música e artista para armazenar o nome do artista da música.
#
# class PlayList: Esta é uma classe que representa uma lista de reprodução. Ela tem dois atributos: head que armazena a referência ao primeiro nó na lista e tail que armazena a referência ao último nó na lista. Se a lista estiver vazia, tanto head quanto tail serão None.
#
# is_empty(self): Este método verifica se a lista está vazia. Ele retorna True se head for None (ou seja, a lista está vazia) e False caso contrário.
#
# append(self, data): Este método adiciona um novo nó ao final da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça e a cauda da lista. Caso contrário, ajusta-se os ponteiros para que o último nó (tail) aponte para o novo nó, o novo nó aponte para o nó anterior (prev_node), e o novo nó se torne a nova cauda da lista.
#
# prepend(self, data): Este método adiciona um novo nó no início da lista. Primeiro, cria-se um novo nó com o valor data. Se a lista estiver vazia (ou seja, head é None), o novo nó se torna a cabeça e a cauda da lista. Caso contrário, ajusta-se os ponteiros para que o primeiro nó (head) aponte para o novo nó, o novo nó aponte para o nó seguinte (next_node), e o novo nó se torne a nova cabeça da lista.
#
# display(self): Este método exibe os elementos da lista. Percorre-se a lista a partir da cabeça e imprime o valor de cada nó.
